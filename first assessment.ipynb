# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Kezia Owusu Nti**
# Clinical Data Scientist

# %% [markdown]
# *I am interested in daa Science because I love to find patterns in things and make meaning.*

# %% [markdown]
# ### This code is to do simple addition.

# %%
1 + 23
# Out:
# 24

# %% [markdown]
# ~~Strikethrough~~
# ***
# 1. Keep Trying
# 2. Don't give up
#     * You are gettting there
# [SN Lab](http://labs.cognitiveclass.ai)
